# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Circuits.csv

# %%
circ_df = pd.read_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Raw Data\\circuits.csv")
circ_df
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# ...

# %%
circ_df.drop(["circuitRef", "lat", "lng", "alt", "url"], axis=1, inplace=True)

# %%
circ_df
# Out:
#     circuitId                                  name      location  \
# 0           1        Albert Park Grand Prix Circuit     Melbourne
# 1           2          Sepang International Circuit  Kuala Lumpur
# 2           3         Bahrain International Circuit        Sakhir
# 3           4        Circuit de Barcelona-Catalunya      Montmeló
# 4           5                         Istanbul Park      Istanbul
# ..        ...                                   ...           ...
# 72         75    Autódromo Internacional do Algarve      Portimão
# 73         76  Autodromo Internazionale del Mugello       Mugello
# 74         77               Jeddah Corniche Circuit        Jeddah
# 75         78          Losail International Circuit     Al Daayen
# 76         79         Miami International Autodrome         Miami
#
#          country
# 0      Australia
# 1       Malaysia
# 2        Bahrain
# 3          Spain
# 4         Turkey
# ..           ...
# 72      Portugal
# 73         Italy
# ...

# %%
circ_df.to_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Cleaned Data\\circuits.csv", index=False)

# %% [markdown]
# ## Constructor_results.csv

# %%
cres_df = pd.read_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Raw Data\\constructor_results.csv")
cres_df
# Out:
#        constructorResultsId  raceId  constructorId  points status
# 0                         1      18              1    14.0     \N
# 1                         2      18              2     8.0     \N
# 2                         3      18              3     9.0     \N
# 3                         4      18              4     5.0     \N
# 4                         5      18              5     2.0     \N
# ...                     ...     ...            ...     ...    ...
# 12620                 17125    1144            210     4.0     \N
# 12621                 17126    1144            117     2.0     \N
# 12622                 17127    1144              3     0.0     \N
# 12623                 17128    1144            215     0.0     \N
# 12624                 17129    1144             15     0.0     \N
#
# [12625 rows x 5 columns]

# %%
cres_df.drop("status", axis = 1, inplace = True)
cres_df
# Out:
#        constructorResultsId  raceId  constructorId  points
# 0                         1      18              1    14.0
# 1                         2      18              2     8.0
# 2                         3      18              3     9.0
# 3                         4      18              4     5.0
# 4                         5      18              5     2.0
# ...                     ...     ...            ...     ...
# 12620                 17125    1144            210     4.0
# 12621                 17126    1144            117     2.0
# 12622                 17127    1144              3     0.0
# 12623                 17128    1144            215     0.0
# 12624                 17129    1144             15     0.0
#
# [12625 rows x 4 columns]

# %%
cres_df.to_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Cleaned Data\\constructor_results.csv", index=False)

# %% [markdown]
# ## Constructors.csv

# %%
con_df = pd.read_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Raw Data\\constructors.csv")
con_df
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
# 211            215             rb      RB F1 Team     Italian
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# ...

# %%
con_df.drop(["constructorRef", "url"], axis = 1, inplace = True)
con_df
# Out:
#      constructorId            name nationality
# 0                1         McLaren     British
# 1                2      BMW Sauber      German
# 2                3        Williams     British
# 3                4         Renault      French
# 4                5      Toro Rosso     Italian
# ..             ...             ...         ...
# 207            210    Haas F1 Team    American
# 208            211    Racing Point     British
# 209            213      AlphaTauri     Italian
# 210            214  Alpine F1 Team      French
# 211            215      RB F1 Team     Italian
#
# [212 rows x 3 columns]

# %%
con_df.to_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Cleaned Data\\constructors.csv", index=False)

# %% [markdown]
# ## Drivers.csv

# %%
dri_df = pd.read_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Raw Data\\drivers.csv")
dri_df
# Out:
#      driverId   driverRef number code  forename     surname         dob  \
# 0           1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...         ...    ...  ...       ...         ...         ...
# 856       858    sargeant      2  SAR     Logan    Sargeant  2000-12-31
# 857       859      lawson     30  LAW      Liam      Lawson  2002-02-11
# 858       860     bearman     38  BEA    Oliver     Bearman  2005-05-08
# 859       861   colapinto     43  COL    Franco   Colapinto  2003-05-27
# 860       862      doohan     61  DOO      Jack      Doohan  2003-01-20
#
#        nationality                                             url
# ...

# %%
dri_df.drop(["number", "url"], axis = 1, inplace = True)
dri_df
# Out:
#      driverId   driverRef code  forename     surname         dob  \
# 0           1    hamilton  HAM     Lewis    Hamilton  1985-01-07
# 1           2    heidfeld  HEI      Nick    Heidfeld  1977-05-10
# 2           3     rosberg  ROS      Nico     Rosberg  1985-06-27
# 3           4      alonso  ALO  Fernando      Alonso  1981-07-29
# 4           5  kovalainen  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...         ...  ...       ...         ...         ...
# 856       858    sargeant  SAR     Logan    Sargeant  2000-12-31
# 857       859      lawson  LAW      Liam      Lawson  2002-02-11
# 858       860     bearman  BEA    Oliver     Bearman  2005-05-08
# 859       861   colapinto  COL    Franco   Colapinto  2003-05-27
# 860       862      doohan  DOO      Jack      Doohan  2003-01-20
#
#        nationality
# 0          British
# 1           German
# 2           German
# 3          Spanish
# 4          Finnish
# ..             ...
# 856       American
# 857  New Zealander
# ...

# %%
dri_df.to_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Cleaned Data\\drivers.csv", index=False)

# %% [markdown]
# ## Races.csv

# %%
race_df = pd.read_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Raw Data\\races.csv")
race_df
# Out:
#       raceId  year  round  circuitId                    name        date  \
# 0          1  2009      1          1   Australian Grand Prix  2009-03-29
# 1          2  2009      2          2    Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17      Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3      Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4      Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                     ...         ...
# 1120    1140  2024     20         32  Mexico City Grand Prix  2024-10-27
# 1121    1141  2024     21         18    São Paulo Grand Prix  2024-11-03
# 1122    1142  2024     22         80    Las Vegas Grand Prix  2024-11-23
# 1123    1143  2024     23         78        Qatar Grand Prix  2024-12-01
# 1124    1144  2024     24         24    Abu Dhabi Grand Prix  2024-12-08
#
#           time                                                url    fp1_date  \
# ...

# %%
race_df.drop(["date", "time", "url"], axis = 1, inplace = True)
race_df
# Out:
#       raceId  year  round  circuitId                    name    fp1_date  \
# 0          1  2009      1          1   Australian Grand Prix          \N
# 1          2  2009      2          2    Malaysian Grand Prix          \N
# 2          3  2009      3         17      Chinese Grand Prix          \N
# 3          4  2009      4          3      Bahrain Grand Prix          \N
# 4          5  2009      5          4      Spanish Grand Prix          \N
# ...      ...   ...    ...        ...                     ...         ...
# 1120    1140  2024     20         32  Mexico City Grand Prix  2024-10-25
# 1121    1141  2024     21         18    São Paulo Grand Prix  2024-11-01
# 1122    1142  2024     22         80    Las Vegas Grand Prix  2024-11-21
# 1123    1143  2024     23         78        Qatar Grand Prix  2024-11-29
# 1124    1144  2024     24         24    Abu Dhabi Grand Prix  2024-12-06
#
#       fp1_time    fp2_date  fp2_time    fp3_date  fp3_time  quali_date  \
# ...

# %%
race_df.to_csv("C:\\Users\\Checkout\\Desktop\\Pet Project\\F1\\Ergast Data\\Cleaned Data\\races.csv", index=False)
